# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./glass.csv')
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
data['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical

y = data['Type']
X = data.drop(['Type'], axis = 1)
X.shape, y.shape
# Out:
# ((214, 9), (214,))

# %%
std = StandardScaler()
X_scaled = std.fit_transform(X)
y_encoded = to_categorical(y)
X_scaled.shape, y_encoded.shape
# Out:
# ((214, 9), (214, 8))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(16, input_shape = (X_train.shape[1],), activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(32, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation = 'sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(512, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(y_train.shape[1], activation = 'softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# /Users/bhagya/Library/Python/3.9/lib/python/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_63 (Dense)                │ (None, 16)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_53 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_54 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_55 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_56 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_57 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_58 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 219,272 (856.53 KB)
#  Trainable params: 219,272 (856.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,
          y_train,
          epochs=100,
          verbose = 1,
          batch_size = 2,
          validation_split = 0.2
          )
# Out:
# Epoch 1/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3617 - loss: 1.8400 - val_accuracy: 0.2571 - val_loss: 1.7077
# Epoch 2/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4275 - loss: 1.6080 - val_accuracy: 0.2571 - val_loss: 1.6251
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3649 - loss: 1.6110 - val_accuracy: 0.3714 - val_loss: 1.5812
# Epoch 4/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3062 - loss: 1.4814 - val_accuracy: 0.2571 - val_loss: 1.6029
# Epoch 5/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3325 - loss: 1.5761 - val_accuracy: 0.2571 - val_loss: 1.5830
# Epoch 6/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2480 - loss: 1.5629 - val_accuracy: 0.2571 - val_loss: 1.5940
# Epoch 7/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3496 - loss: 1.5761 - val_accuracy: 0.3714 - val_loss: 1.5089
# Epoch 8/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3455 - loss: 1.4975 - val_accuracy: 0.3714 - val_loss: 1.5329
# Epoch 9/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4196 - loss: 1.4816 - val_accuracy: 0.2571 - val_loss: 1.5589
# Epoch 10/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2956 - loss: 1.5894 - val_accuracy: 0.3714 - val_loss: 1.5235
# Epoch 11/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4080 - loss: 1.4518 - val_accuracy: 0.3714 - val_loss: 1.5368
# Epoch 12/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3221 - loss: 1.5936 - val_accuracy: 0.2571 - val_loss: 1.5094
# Epoch 13/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3867 - loss: 1.4557 - val_accuracy: 0.2571 - val_loss: 1.5321
# Epoch 14/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2619 - loss: 1.5053 - val_accuracy: 0.4000 - val_loss: 1.4218
# Epoch 15/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4000 - loss: 1.3417 - val_accuracy: 0.4571 - val_loss: 1.3900
# Epoch 16/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3820 - loss: 1.3064 - val_accuracy: 0.4571 - val_loss: 1.3186
# Epoch 17/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4858 - loss: 1.3561 - val_accuracy: 0.4571 - val_loss: 1.2228
# Epoch 18/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5037 - loss: 1.3298 - val_accuracy: 0.4286 - val_loss: 1.2182
# Epoch 19/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4814 - loss: 1.1394 - val_accuracy: 0.4857 - val_loss: 1.3014
# Epoch 20/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4411 - loss: 1.3250 - val_accuracy: 0.4571 - val_loss: 1.2490
# Epoch 21/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4064 - loss: 1.1772 - val_accuracy: 0.4571 - val_loss: 1.2038
# Epoch 22/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5138 - loss: 1.1824 - val_accuracy: 0.4286 - val_loss: 1.2441
# Epoch 23/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5220 - loss: 1.1670 - val_accuracy: 0.4571 - val_loss: 1.2226
# Epoch 24/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5842 - loss: 1.1916 - val_accuracy: 0.4571 - val_loss: 1.2551
# Epoch 25/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4482 - loss: 1.1030 - val_accuracy: 0.4857 - val_loss: 1.2103
# Epoch 26/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5017 - loss: 1.1389 - val_accuracy: 0.4571 - val_loss: 1.2247
# Epoch 27/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5878 - loss: 1.0649 - val_accuracy: 0.5143 - val_loss: 1.2336
# Epoch 28/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5174 - loss: 1.2358 - val_accuracy: 0.4857 - val_loss: 1.2588
# Epoch 29/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5356 - loss: 1.1179 - val_accuracy: 0.4857 - val_loss: 1.2701
# Epoch 30/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5326 - loss: 1.0716 - val_accuracy: 0.5143 - val_loss: 1.2004
# Epoch 31/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5399 - loss: 1.2232 - val_accuracy: 0.4571 - val_loss: 1.2193
# Epoch 32/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5765 - loss: 0.9245 - val_accuracy: 0.4857 - val_loss: 1.2198
# Epoch 33/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4749 - loss: 1.2336 - val_accuracy: 0.4857 - val_loss: 1.2379
# Epoch 34/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5517 - loss: 1.1488 - val_accuracy: 0.4857 - val_loss: 1.2462
# Epoch 35/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5160 - loss: 1.1500 - val_accuracy: 0.4857 - val_loss: 1.4208
# Epoch 36/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5344 - loss: 1.0131 - val_accuracy: 0.4571 - val_loss: 1.2632
# Epoch 37/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3807 - loss: 1.2209 - val_accuracy: 0.4857 - val_loss: 1.2765
# Epoch 38/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6025 - loss: 1.0383 - val_accuracy: 0.4857 - val_loss: 1.3540
# Epoch 39/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4393 - loss: 1.1671 - val_accuracy: 0.4286 - val_loss: 1.3275
# Epoch 40/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6027 - loss: 0.9253 - val_accuracy: 0.4571 - val_loss: 1.3309
# Epoch 41/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5225 - loss: 1.1335 - val_accuracy: 0.5143 - val_loss: 1.2951
# Epoch 42/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4211 - loss: 1.1662 - val_accuracy: 0.4857 - val_loss: 1.3810
# Epoch 43/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5011 - loss: 1.0686 - val_accuracy: 0.4571 - val_loss: 1.3124
# Epoch 44/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4324 - loss: 1.1789 - val_accuracy: 0.4857 - val_loss: 1.3046
# Epoch 45/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4404 - loss: 1.0545 - val_accuracy: 0.4571 - val_loss: 1.4585
# Epoch 46/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4967 - loss: 1.0123 - val_accuracy: 0.4857 - val_loss: 1.3223
# Epoch 47/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5003 - loss: 1.0222 - val_accuracy: 0.4286 - val_loss: 1.4141
# Epoch 48/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5726 - loss: 1.0243 - val_accuracy: 0.5143 - val_loss: 1.3488
# Epoch 49/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6494 - loss: 0.8867 - val_accuracy: 0.4857 - val_loss: 1.3605
# Epoch 50/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5652 - loss: 0.9929 - val_accuracy: 0.6000 - val_loss: 1.3141
# Epoch 51/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5916 - loss: 0.9691 - val_accuracy: 0.4571 - val_loss: 1.3371
# Epoch 52/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3985 - loss: 1.2025 - val_accuracy: 0.4857 - val_loss: 1.4079
# Epoch 53/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5123 - loss: 1.0714 - val_accuracy: 0.4571 - val_loss: 1.4971
# Epoch 54/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5866 - loss: 1.0339 - val_accuracy: 0.5143 - val_loss: 1.2943
# Epoch 55/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5696 - loss: 1.0539 - val_accuracy: 0.4571 - val_loss: 1.3218
# Epoch 56/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6091 - loss: 1.0684 - val_accuracy: 0.5429 - val_loss: 1.2693
# Epoch 57/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5868 - loss: 1.0000 - val_accuracy: 0.4857 - val_loss: 1.4881
# Epoch 58/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5206 - loss: 1.1186 - val_accuracy: 0.4857 - val_loss: 1.5206
# Epoch 59/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4928 - loss: 1.0889 - val_accuracy: 0.5143 - val_loss: 1.3999
# Epoch 60/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4921 - loss: 1.2164 - val_accuracy: 0.4857 - val_loss: 1.3879
# Epoch 61/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5617 - loss: 1.0146 - val_accuracy: 0.4857 - val_loss: 1.3367
# Epoch 62/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5055 - loss: 1.0363 - val_accuracy: 0.4571 - val_loss: 1.3940
# Epoch 63/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5957 - loss: 1.0024 - val_accuracy: 0.5429 - val_loss: 1.2586
# Epoch 64/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5760 - loss: 1.0476 - val_accuracy: 0.4571 - val_loss: 1.2961
# Epoch 65/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5623 - loss: 1.0162 - val_accuracy: 0.4857 - val_loss: 1.2692
# Epoch 66/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4561 - loss: 1.0456 - val_accuracy: 0.4857 - val_loss: 1.3896
# Epoch 67/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5552 - loss: 0.9967 - val_accuracy: 0.5143 - val_loss: 1.3483
# Epoch 68/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4879 - loss: 1.0949 - val_accuracy: 0.5143 - val_loss: 1.3749
# Epoch 69/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4987 - loss: 1.1671 - val_accuracy: 0.5143 - val_loss: 1.3538
# Epoch 70/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5260 - loss: 1.0322 - val_accuracy: 0.4857 - val_loss: 1.4203
# Epoch 71/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5107 - loss: 1.0092 - val_accuracy: 0.5143 - val_loss: 1.3280
# Epoch 72/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5338 - loss: 0.9989 - val_accuracy: 0.4571 - val_loss: 1.3283
# Epoch 73/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5598 - loss: 1.0079 - val_accuracy: 0.4857 - val_loss: 1.2572
# Epoch 74/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4578 - loss: 1.0341 - val_accuracy: 0.4571 - val_loss: 1.4211
# Epoch 75/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4814 - loss: 1.0098 - val_accuracy: 0.4571 - val_loss: 1.3850
# Epoch 76/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5830 - loss: 0.9819 - val_accuracy: 0.4571 - val_loss: 1.4127
# Epoch 77/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3806 - loss: 1.2790 - val_accuracy: 0.4857 - val_loss: 1.3115
# Epoch 78/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5258 - loss: 1.0937 - val_accuracy: 0.4857 - val_loss: 1.3476
# Epoch 79/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4756 - loss: 1.0270 - val_accuracy: 0.4857 - val_loss: 1.3093
# Epoch 80/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5089 - loss: 1.0560 - val_accuracy: 0.4571 - val_loss: 1.4547
# Epoch 81/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5525 - loss: 1.0224 - val_accuracy: 0.4857 - val_loss: 1.4014
# Epoch 82/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5196 - loss: 0.8930 - val_accuracy: 0.4571 - val_loss: 1.4555
# Epoch 83/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5381 - loss: 0.9638 - val_accuracy: 0.4857 - val_loss: 1.4307
# Epoch 84/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6160 - loss: 0.9282 - val_accuracy: 0.4857 - val_loss: 1.4491
# Epoch 85/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6117 - loss: 0.8452 - val_accuracy: 0.4857 - val_loss: 1.4349
# Epoch 86/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.9701 - val_accuracy: 0.4857 - val_loss: 1.4776
# Epoch 87/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5313 - loss: 1.0063 - val_accuracy: 0.4571 - val_loss: 1.5290
# Epoch 88/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5047 - loss: 1.0446 - val_accuracy: 0.4571 - val_loss: 1.5084
# Epoch 89/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4969 - loss: 0.9244 - val_accuracy: 0.5143 - val_loss: 1.2611
# Epoch 90/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6154 - loss: 0.9908 - val_accuracy: 0.4571 - val_loss: 1.4349
# Epoch 91/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4599 - loss: 1.0940 - val_accuracy: 0.4571 - val_loss: 1.3744
# Epoch 92/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4162 - loss: 1.1161 - val_accuracy: 0.4571 - val_loss: 1.3966
# Epoch 93/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3786 - loss: 1.0573 - val_accuracy: 0.5143 - val_loss: 1.4518
# Epoch 94/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5729 - loss: 0.9556 - val_accuracy: 0.4857 - val_loss: 1.3765
# Epoch 95/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5933 - loss: 0.9330 - val_accuracy: 0.4857 - val_loss: 1.5311
# Epoch 96/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4955 - loss: 1.0663 - val_accuracy: 0.5143 - val_loss: 1.4597
# Epoch 97/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5678 - loss: 0.9795 - val_accuracy: 0.5143 - val_loss: 1.3448
# Epoch 98/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5415 - loss: 0.9994 - val_accuracy: 0.4571 - val_loss: 1.4088
# Epoch 99/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6114 - loss: 0.9720 - val_accuracy: 0.4571 - val_loss: 1.4878
# Epoch 100/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5780 - loss: 0.9102 - val_accuracy: 0.4286 - val_loss: 1.7465

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5337 - loss: 0.9382
# [0.9586917757987976, 0.5348837375640869]
